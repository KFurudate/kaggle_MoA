# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
import lightgbm as lgb

# %%
train = pd.read_csv("../input/lish-moa/train_features.csv")
test = pd.read_csv("../input/lish-moa/test_features.csv")
train_targets_scored = pd.read_csv("../input/lish-moa/train_targets_scored.csv")
train_targets_nonscored = pd.read_csv("../input/lish-moa/train_targets_nonscored.csv")
sub = pd.read_csv("../input/lish-moa/sample_submission.csv")

# %%
def label_encoding(train: pd.DataFrame, test: pd.DataFrame, encode_cols):
    n_train = len(train)
    train = pd.concat([train, test], sort=False).reset_index(drop=True)
    for f in encode_cols:
        try:
            lbl = preprocessing.LabelEncoder()
            train[f] = lbl.fit_transform(list(train[f].values))
        except:
            print(f)
    test = train[n_train:].reset_index(drop=True)
    train = train[:n_train]
    return train, test

# %%
def run_lgbm(target_col: str):
    
    X_train = train.drop(["sig_id"], axis=1)
    y_train = train_targets_scored[target_col]
    X_test = test.drop(["sig_id"], axis=1)

    y_preds = []
    models = []
    oof_train = np.zeros((len(X_train),))

    for fold_id, (train_index, valid_index) in enumerate(cv.split(X_train)):
        X_tr = X_train.loc[train_index, :]
        X_val = X_train.loc[valid_index, :]
        y_tr = y_train[train_index]
        y_val = y_train[valid_index]

        lgb_train = lgb.Dataset(X_tr,
                                y_tr,
                                categorical_feature=categorical_cols)

        lgb_eval = lgb.Dataset(X_val,
                               y_val,
                               reference=lgb_train,
                               categorical_feature=categorical_cols)

        model = lgb.train(params,
                          lgb_train,
                          valid_sets=[lgb_train, lgb_eval],
                          verbose_eval=10,
                          num_boost_round=1000,
                          early_stopping_rounds=10)


        oof_train[valid_index] = model.predict(X_val,
                                               num_iteration=model.best_iteration)
        y_pred = model.predict(X_test,
                               num_iteration=model.best_iteration)

        y_preds.append(y_pred)
        models.append(model)

    return oof_train, sum(y_preds) / len(y_preds)

# %% [markdown]
# # Preprocessing
#
# We have to convert some categorical features into numbers in train and test. We can identify categorical features by `pd.DataFrame.select_dtypes`.

# %%
train.head()
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.1944 -1.0120  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  1.0190  0.5207  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0323  1.2390  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  4.0620 -0.8095  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  1.4180 -0.8244  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# 1  0.1522  0.1241  0.6077  0.7371
# 2 -0.6417 -0.2187 -1.4080  0.6931
# 3 -1.6210 -0.8784 -0.3876 -0.8154
# 4  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 876 columns]

# %%
train.select_dtypes(include=['object']).columns
# Out:
# Index(['sig_id', 'cp_type', 'cp_dose'], dtype='object')

# %%
train, test = label_encoding(train, test, ['cp_type', 'cp_dose'])

# %%
train.head()
# Out:
#          sig_id  cp_type  cp_time  cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2        1       24        0  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc        1       72        0  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a        1       48        0  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391        1       48        0 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3        1       72        1 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.1944 -1.0120  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  1.0190  0.5207  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0323  1.2390  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  4.0620 -0.8095  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  1.4180 -0.8244  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# 1  0.1522  0.1241  0.6077  0.7371
# 2 -0.6417 -0.2187 -1.4080  0.6931
# 3 -1.6210 -0.8784 -0.3876 -0.8154
# 4  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 876 columns]

# %% [markdown]
# # Modeling

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=0)

params = {
    'num_leaves': 24,
    'max_depth': 5,
    'objective': 'binary',
    'learning_rate': 0.01
}

categorical_cols = ['cp_type', 'cp_dose']
oof = train_targets_scored.copy()

# %%
for target_col in train_targets_scored.columns:
    if target_col != "sig_id":
        _oof, _preds = run_lgbm(target_col)
        oof[target_col] = _oof
        sub[target_col] = _preds
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00243302	valid_1's binary_logloss: 0.00686394
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00482727	valid_1's binary_logloss: 0.00681477
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00271013	valid_1's binary_logloss: 0.00531191
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00531181	valid_1's binary_logloss: 0.00528695
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00237786	valid_1's binary_logloss: 0.00832212
# [20]	training's binary_logloss: 0.00178391	valid_1's binary_logloss: 0.00831437
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.00228256	valid_1's binary_logloss: 0.00831379
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00244813	valid_1's binary_logloss: 0.0067476
# Early stopping, best iteration is:
# [9]	training's binary_logloss: 0.00254212	valid_1's binary_logloss: 0.00674496
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00323863	valid_1's binary_logloss: 0.00219852
# [20]	training's binary_logloss: 0.00243033	valid_1's binary_logloss: 0.00214574
# [30]	training's binary_logloss: 0.00200218	valid_1's binary_logloss: 0.00206598
# [40]	training's binary_logloss: 0.00170091	valid_1's binary_logloss: 0.00194336
# [50]	training's binary_logloss: 0.00149375	valid_1's binary_logloss: 0.00189888
# [60]	training's binary_logloss: 0.00132546	valid_1's binary_logloss: 0.00184009
# [70]	training's binary_logloss: 0.00118434	valid_1's binary_logloss: 0.00178768
# [80]	training's binary_logloss: 0.00106394	valid_1's binary_logloss: 0.00175249
# [90]	training's binary_logloss: 0.000959704	valid_1's binary_logloss: 0.00170428
# [100]	training's binary_logloss: 0.000868405	valid_1's binary_logloss: 0.00167171
# [110]	training's binary_logloss: 0.000788222	valid_1's binary_logloss: 0.00164282
# [120]	training's binary_logloss: 0.000716131	valid_1's binary_logloss: 0.00162161
# [130]	training's binary_logloss: 0.000651438	valid_1's binary_logloss: 0.00160246
# [140]	training's binary_logloss: 0.000592322	valid_1's binary_logloss: 0.0015947
# [150]	training's binary_logloss: 0.000540005	valid_1's binary_logloss: 0.00158935
# [160]	training's binary_logloss: 0.000492083	valid_1's binary_logloss: 0.00158552
# [170]	training's binary_logloss: 0.000449646	valid_1's binary_logloss: 0.00158382
# Early stopping, best iteration is:
# [161]	training's binary_logloss: 0.000487681	valid_1's binary_logloss: 0.00158133
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00342895	valid_1's binary_logloss: 0.00513013
# [20]	training's binary_logloss: 0.00246385	valid_1's binary_logloss: 0.00508498
# [30]	training's binary_logloss: 0.00206923	valid_1's binary_logloss: 0.00506459
# [40]	training's binary_logloss: 0.00179436	valid_1's binary_logloss: 0.00502946
# [50]	training's binary_logloss: 0.00158058	valid_1's binary_logloss: 0.00499873
# [60]	training's binary_logloss: 0.00140745	valid_1's binary_logloss: 0.00496916
# [70]	training's binary_logloss: 0.00125798	valid_1's binary_logloss: 0.00496602
# Early stopping, best iteration is:
# [67]	training's binary_logloss: 0.0013015	valid_1's binary_logloss: 0.00495932
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00258373	valid_1's binary_logloss: 0.00990656
# Early stopping, best iteration is:
# [8]	training's binary_logloss: 0.00291476	valid_1's binary_logloss: 0.00988897
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00319882	valid_1's binary_logloss: 0.00686229
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00527698	valid_1's binary_logloss: 0.00680858
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00307058	valid_1's binary_logloss: 0.00512022
# Early stopping, best iteration is:
# [5]	training's binary_logloss: 0.00398334	valid_1's binary_logloss: 0.00510832
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00388768	valid_1's binary_logloss: 0.00383723
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00631853	valid_1's binary_logloss: 0.00382038
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00502873	valid_1's binary_logloss: 0.00830504
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00707917	valid_1's binary_logloss: 0.0082669
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00551254	valid_1's binary_logloss: 0.00543184
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00804028	valid_1's binary_logloss: 0.00540231
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00430623	valid_1's binary_logloss: 0.00832582
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00732215	valid_1's binary_logloss: 0.0082644
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00307089	valid_1's binary_logloss: 0.0144364
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00539983	valid_1's binary_logloss: 0.0143084
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00567726	valid_1's binary_logloss: 0.00401324
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00842494	valid_1's binary_logloss: 0.00400222
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0444037	valid_1's binary_logloss: 0.0463741
# [20]	training's binary_logloss: 0.0423566	valid_1's binary_logloss: 0.0462106
# [30]	training's binary_logloss: 0.0404905	valid_1's binary_logloss: 0.0462017
# [40]	training's binary_logloss: 0.0385664	valid_1's binary_logloss: 0.0461566
# [50]	training's binary_logloss: 0.0369957	valid_1's binary_logloss: 0.0460907
# [60]	training's binary_logloss: 0.0351798	valid_1's binary_logloss: 0.0460062
# [70]	training's binary_logloss: 0.0337123	valid_1's binary_logloss: 0.0459938
# [80]	training's binary_logloss: 0.0322776	valid_1's binary_logloss: 0.0458907
# [90]	training's binary_logloss: 0.0309007	valid_1's binary_logloss: 0.0458744
# [100]	training's binary_logloss: 0.0296854	valid_1's binary_logloss: 0.0458079
# [110]	training's binary_logloss: 0.0285428	valid_1's binary_logloss: 0.0456724
# [120]	training's binary_logloss: 0.0274359	valid_1's binary_logloss: 0.0455773
# [130]	training's binary_logloss: 0.0263108	valid_1's binary_logloss: 0.0455134
# [140]	training's binary_logloss: 0.0253488	valid_1's binary_logloss: 0.0454405
# [150]	training's binary_logloss: 0.0244646	valid_1's binary_logloss: 0.0453874
# [160]	training's binary_logloss: 0.0235272	valid_1's binary_logloss: 0.0453672
# [170]	training's binary_logloss: 0.0227124	valid_1's binary_logloss: 0.0453668
# [180]	training's binary_logloss: 0.0219157	valid_1's binary_logloss: 0.0453656
# Early stopping, best iteration is:
# [176]	training's binary_logloss: 0.0222561	valid_1's binary_logloss: 0.0453449
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0462694	valid_1's binary_logloss: 0.0404014
# [20]	training's binary_logloss: 0.0440595	valid_1's binary_logloss: 0.0402697
# [30]	training's binary_logloss: 0.0421065	valid_1's binary_logloss: 0.0401693
# [40]	training's binary_logloss: 0.0405307	valid_1's binary_logloss: 0.0401201
# [50]	training's binary_logloss: 0.0388163	valid_1's binary_logloss: 0.0400606
# [60]	training's binary_logloss: 0.0374659	valid_1's binary_logloss: 0.0400442
# [70]	training's binary_logloss: 0.0360457	valid_1's binary_logloss: 0.0399854
# [80]	training's binary_logloss: 0.0345582	valid_1's binary_logloss: 0.0399289
# [90]	training's binary_logloss: 0.0332398	valid_1's binary_logloss: 0.0398533
# [100]	training's binary_logloss: 0.0320395	valid_1's binary_logloss: 0.0398262
# [110]	training's binary_logloss: 0.0308033	valid_1's binary_logloss: 0.0397431
# [120]	training's binary_logloss: 0.0297893	valid_1's binary_logloss: 0.039677
# Early stopping, best iteration is:
# [119]	training's binary_logloss: 0.0298633	valid_1's binary_logloss: 0.0396716
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0419179	valid_1's binary_logloss: 0.0556618
# [20]	training's binary_logloss: 0.0397746	valid_1's binary_logloss: 0.0555577
# [30]	training's binary_logloss: 0.0378383	valid_1's binary_logloss: 0.0552925
# [40]	training's binary_logloss: 0.0359946	valid_1's binary_logloss: 0.055119
# [50]	training's binary_logloss: 0.0342249	valid_1's binary_logloss: 0.0548496
# [60]	training's binary_logloss: 0.0328264	valid_1's binary_logloss: 0.054547
# [70]	training's binary_logloss: 0.0315035	valid_1's binary_logloss: 0.0543963
# [80]	training's binary_logloss: 0.0302661	valid_1's binary_logloss: 0.0543524
# [90]	training's binary_logloss: 0.0293051	valid_1's binary_logloss: 0.0542842
# [100]	training's binary_logloss: 0.0281689	valid_1's binary_logloss: 0.0542092
# [110]	training's binary_logloss: 0.0270396	valid_1's binary_logloss: 0.0540846
# Early stopping, best iteration is:
# [109]	training's binary_logloss: 0.0271769	valid_1's binary_logloss: 0.0540729
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0438581	valid_1's binary_logloss: 0.0464075
# [20]	training's binary_logloss: 0.0414158	valid_1's binary_logloss: 0.0463026
# [30]	training's binary_logloss: 0.0394494	valid_1's binary_logloss: 0.0462244
# [40]	training's binary_logloss: 0.037789	valid_1's binary_logloss: 0.0461401
# Early stopping, best iteration is:
# [39]	training's binary_logloss: 0.0379703	valid_1's binary_logloss: 0.0461167
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0452187	valid_1's binary_logloss: 0.0434473
# [20]	training's binary_logloss: 0.0430432	valid_1's binary_logloss: 0.0433163
# [30]	training's binary_logloss: 0.0414464	valid_1's binary_logloss: 0.0431448
# [40]	training's binary_logloss: 0.0399266	valid_1's binary_logloss: 0.042945
# [50]	training's binary_logloss: 0.0384786	valid_1's binary_logloss: 0.0428337
# [60]	training's binary_logloss: 0.0369455	valid_1's binary_logloss: 0.0428001
# [70]	training's binary_logloss: 0.0357029	valid_1's binary_logloss: 0.0426371
# [80]	training's binary_logloss: 0.0342872	valid_1's binary_logloss: 0.0425512
# [90]	training's binary_logloss: 0.0329258	valid_1's binary_logloss: 0.0424328
# [100]	training's binary_logloss: 0.0316838	valid_1's binary_logloss: 0.0423413
# [110]	training's binary_logloss: 0.0304528	valid_1's binary_logloss: 0.0423416
# Early stopping, best iteration is:
# [103]	training's binary_logloss: 0.0312779	valid_1's binary_logloss: 0.0423257
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.066553	valid_1's binary_logloss: 0.0592998
# [20]	training's binary_logloss: 0.0644085	valid_1's binary_logloss: 0.0591684
# [30]	training's binary_logloss: 0.0623526	valid_1's binary_logloss: 0.0590664
# [40]	training's binary_logloss: 0.0604475	valid_1's binary_logloss: 0.0590011
# [50]	training's binary_logloss: 0.0589862	valid_1's binary_logloss: 0.0589174
# [60]	training's binary_logloss: 0.0577701	valid_1's binary_logloss: 0.0588054
# [70]	training's binary_logloss: 0.0564116	valid_1's binary_logloss: 0.0586991
# [80]	training's binary_logloss: 0.0551198	valid_1's binary_logloss: 0.0586253
# [90]	training's binary_logloss: 0.0537617	valid_1's binary_logloss: 0.0585776
# [100]	training's binary_logloss: 0.0526225	valid_1's binary_logloss: 0.0585047
# [110]	training's binary_logloss: 0.0515196	valid_1's binary_logloss: 0.0583979
# [120]	training's binary_logloss: 0.0504171	valid_1's binary_logloss: 0.0583315
# [130]	training's binary_logloss: 0.0492001	valid_1's binary_logloss: 0.0582492
# [140]	training's binary_logloss: 0.0481192	valid_1's binary_logloss: 0.0582233
# [150]	training's binary_logloss: 0.0470781	valid_1's binary_logloss: 0.0581363
# [160]	training's binary_logloss: 0.0460762	valid_1's binary_logloss: 0.0580852
# [170]	training's binary_logloss: 0.0452315	valid_1's binary_logloss: 0.0580215
# [180]	training's binary_logloss: 0.044362	valid_1's binary_logloss: 0.0580061
# [190]	training's binary_logloss: 0.0435586	valid_1's binary_logloss: 0.0579658
# [200]	training's binary_logloss: 0.0427643	valid_1's binary_logloss: 0.057976
# Early stopping, best iteration is:
# [190]	training's binary_logloss: 0.0435586	valid_1's binary_logloss: 0.0579658
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0653933	valid_1's binary_logloss: 0.0672948
# [20]	training's binary_logloss: 0.0632821	valid_1's binary_logloss: 0.0670384
# [30]	training's binary_logloss: 0.0609386	valid_1's binary_logloss: 0.066878
# [40]	training's binary_logloss: 0.0590432	valid_1's binary_logloss: 0.0667389
# [50]	training's binary_logloss: 0.0576263	valid_1's binary_logloss: 0.0665742
# [60]	training's binary_logloss: 0.0560676	valid_1's binary_logloss: 0.0664522
# [70]	training's binary_logloss: 0.0546604	valid_1's binary_logloss: 0.0663317
# [80]	training's binary_logloss: 0.053112	valid_1's binary_logloss: 0.0662561
# Early stopping, best iteration is:
# [79]	training's binary_logloss: 0.0533631	valid_1's binary_logloss: 0.0662408
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0639452	valid_1's binary_logloss: 0.0728728
# [20]	training's binary_logloss: 0.0616081	valid_1's binary_logloss: 0.0727268
# [30]	training's binary_logloss: 0.0592764	valid_1's binary_logloss: 0.0725699
# [40]	training's binary_logloss: 0.057244	valid_1's binary_logloss: 0.0724091
# [50]	training's binary_logloss: 0.0557185	valid_1's binary_logloss: 0.0722047
# [60]	training's binary_logloss: 0.0544167	valid_1's binary_logloss: 0.071947
# [70]	training's binary_logloss: 0.0531402	valid_1's binary_logloss: 0.0718341
# [80]	training's binary_logloss: 0.0519366	valid_1's binary_logloss: 0.0716669
# [90]	training's binary_logloss: 0.050888	valid_1's binary_logloss: 0.071516
# [100]	training's binary_logloss: 0.0499162	valid_1's binary_logloss: 0.0713198
# [110]	training's binary_logloss: 0.0489021	valid_1's binary_logloss: 0.0712545
# [120]	training's binary_logloss: 0.047969	valid_1's binary_logloss: 0.0711862
# [130]	training's binary_logloss: 0.046989	valid_1's binary_logloss: 0.0710475
# [140]	training's binary_logloss: 0.0458886	valid_1's binary_logloss: 0.0710591
# Early stopping, best iteration is:
# [135]	training's binary_logloss: 0.0464683	valid_1's binary_logloss: 0.070996
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0658916	valid_1's binary_logloss: 0.0630308
# [20]	training's binary_logloss: 0.0633978	valid_1's binary_logloss: 0.062893
# [30]	training's binary_logloss: 0.0613376	valid_1's binary_logloss: 0.062721
# [40]	training's binary_logloss: 0.0594995	valid_1's binary_logloss: 0.0625874
# [50]	training's binary_logloss: 0.0580686	valid_1's binary_logloss: 0.0624864
# [60]	training's binary_logloss: 0.0568352	valid_1's binary_logloss: 0.0623193
# [70]	training's binary_logloss: 0.0556259	valid_1's binary_logloss: 0.0620878
# [80]	training's binary_logloss: 0.054364	valid_1's binary_logloss: 0.0619415
# [90]	training's binary_logloss: 0.0532197	valid_1's binary_logloss: 0.0618949
# [100]	training's binary_logloss: 0.0521869	valid_1's binary_logloss: 0.0617967
# [110]	training's binary_logloss: 0.0508996	valid_1's binary_logloss: 0.0617122
# [120]	training's binary_logloss: 0.0497207	valid_1's binary_logloss: 0.0615676
# [130]	training's binary_logloss: 0.0485719	valid_1's binary_logloss: 0.0613869
# [140]	training's binary_logloss: 0.0473554	valid_1's binary_logloss: 0.0613216
# [150]	training's binary_logloss: 0.0463069	valid_1's binary_logloss: 0.0612706
# [160]	training's binary_logloss: 0.0452651	valid_1's binary_logloss: 0.0612502
# [170]	training's binary_logloss: 0.0441907	valid_1's binary_logloss: 0.0611828
# [180]	training's binary_logloss: 0.0432246	valid_1's binary_logloss: 0.0611211
# [190]	training's binary_logloss: 0.0423153	valid_1's binary_logloss: 0.0610583
# [200]	training's binary_logloss: 0.0416093	valid_1's binary_logloss: 0.0610342
# [210]	training's binary_logloss: 0.0407924	valid_1's binary_logloss: 0.0610026
# Early stopping, best iteration is:
# [209]	training's binary_logloss: 0.0408274	valid_1's binary_logloss: 0.0610019
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.063701	valid_1's binary_logloss: 0.0756461
# [20]	training's binary_logloss: 0.0614803	valid_1's binary_logloss: 0.0753569
# [30]	training's binary_logloss: 0.0594652	valid_1's binary_logloss: 0.0752502
# [40]	training's binary_logloss: 0.0577776	valid_1's binary_logloss: 0.0752049
# [50]	training's binary_logloss: 0.0563018	valid_1's binary_logloss: 0.0751279
# [60]	training's binary_logloss: 0.0549282	valid_1's binary_logloss: 0.0749875
# [70]	training's binary_logloss: 0.0536607	valid_1's binary_logloss: 0.0749476
# [80]	training's binary_logloss: 0.0523654	valid_1's binary_logloss: 0.0748294
# [90]	training's binary_logloss: 0.0510532	valid_1's binary_logloss: 0.0747798
# [100]	training's binary_logloss: 0.0497222	valid_1's binary_logloss: 0.074719
# [110]	training's binary_logloss: 0.0485794	valid_1's binary_logloss: 0.074703
# Early stopping, best iteration is:
# [108]	training's binary_logloss: 0.0487379	valid_1's binary_logloss: 0.0746904
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0165311	valid_1's binary_logloss: 0.0226887
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0196266	valid_1's binary_logloss: 0.0225348
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0172352	valid_1's binary_logloss: 0.0201052
# Early stopping, best iteration is:
# [3]	training's binary_logloss: 0.0202668	valid_1's binary_logloss: 0.0200225
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0179605	valid_1's binary_logloss: 0.0142523
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0221745	valid_1's binary_logloss: 0.0141371
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.016613	valid_1's binary_logloss: 0.0262473
# Early stopping, best iteration is:
# [2]	training's binary_logloss: 0.0183285	valid_1's binary_logloss: 0.0261825
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0159812	valid_1's binary_logloss: 0.0214771
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0203353	valid_1's binary_logloss: 0.0212997
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0135225	valid_1's binary_logloss: 0.0101035
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0170174	valid_1's binary_logloss: 0.0100279
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0126236	valid_1's binary_logloss: 0.0201565
# Early stopping, best iteration is:
# [8]	training's binary_logloss: 0.0131545	valid_1's binary_logloss: 0.0201348
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0113516	valid_1's binary_logloss: 0.0187647
# Early stopping, best iteration is:
# [8]	training's binary_logloss: 0.0121139	valid_1's binary_logloss: 0.0187374
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0112378	valid_1's binary_logloss: 0.0177365
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.015234	valid_1's binary_logloss: 0.0176181
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0123085	valid_1's binary_logloss: 0.0138976
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0162296	valid_1's binary_logloss: 0.0138028
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0243311	valid_1's binary_logloss: 0.0180197
# [20]	training's binary_logloss: 0.0213952	valid_1's binary_logloss: 0.0179259
# [30]	training's binary_logloss: 0.0190614	valid_1's binary_logloss: 0.0178888
# [40]	training's binary_logloss: 0.0171914	valid_1's binary_logloss: 0.0178105
# [50]	training's binary_logloss: 0.0155957	valid_1's binary_logloss: 0.0176932
# [60]	training's binary_logloss: 0.0142545	valid_1's binary_logloss: 0.0176467
# [70]	training's binary_logloss: 0.0131452	valid_1's binary_logloss: 0.0175947
# [80]	training's binary_logloss: 0.0121994	valid_1's binary_logloss: 0.0175361
# [90]	training's binary_logloss: 0.0113747	valid_1's binary_logloss: 0.0175112
# [100]	training's binary_logloss: 0.0106648	valid_1's binary_logloss: 0.0174564
# [110]	training's binary_logloss: 0.0100094	valid_1's binary_logloss: 0.01742
# [120]	training's binary_logloss: 0.00953722	valid_1's binary_logloss: 0.0173587
# [130]	training's binary_logloss: 0.00907434	valid_1's binary_logloss: 0.0173053
# [140]	training's binary_logloss: 0.00861541	valid_1's binary_logloss: 0.0172557
# [150]	training's binary_logloss: 0.00819513	valid_1's binary_logloss: 0.017209
# [160]	training's binary_logloss: 0.00782031	valid_1's binary_logloss: 0.0171468
# [170]	training's binary_logloss: 0.00740658	valid_1's binary_logloss: 0.0171193
# [180]	training's binary_logloss: 0.00705878	valid_1's binary_logloss: 0.017087
# [190]	training's binary_logloss: 0.00675503	valid_1's binary_logloss: 0.0170838
# Early stopping, best iteration is:
# [184]	training's binary_logloss: 0.0069288	valid_1's binary_logloss: 0.0170797
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0245973	valid_1's binary_logloss: 0.0192642
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0277341	valid_1's binary_logloss: 0.0191988
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0211619	valid_1's binary_logloss: 0.028341
# [20]	training's binary_logloss: 0.0192306	valid_1's binary_logloss: 0.0280625
# [30]	training's binary_logloss: 0.0173264	valid_1's binary_logloss: 0.0279132
# [40]	training's binary_logloss: 0.0157407	valid_1's binary_logloss: 0.0277347
# [50]	training's binary_logloss: 0.0143137	valid_1's binary_logloss: 0.0276977
# [60]	training's binary_logloss: 0.0130753	valid_1's binary_logloss: 0.0275971
# [70]	training's binary_logloss: 0.0121141	valid_1's binary_logloss: 0.0273993
# [80]	training's binary_logloss: 0.0112536	valid_1's binary_logloss: 0.0273769
# Early stopping, best iteration is:
# [77]	training's binary_logloss: 0.0115246	valid_1's binary_logloss: 0.0273705
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0209882	valid_1's binary_logloss: 0.0354302
# [20]	training's binary_logloss: 0.0186852	valid_1's binary_logloss: 0.0353468
# [30]	training's binary_logloss: 0.0164234	valid_1's binary_logloss: 0.0353259
# [40]	training's binary_logloss: 0.0146634	valid_1's binary_logloss: 0.0353334
# Early stopping, best iteration is:
# [34]	training's binary_logloss: 0.0156725	valid_1's binary_logloss: 0.0353111
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0220171	valid_1's binary_logloss: 0.0308563
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0247951	valid_1's binary_logloss: 0.0307098
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00189135	valid_1's binary_logloss: 0.00219425
# [20]	training's binary_logloss: 0.00148848	valid_1's binary_logloss: 0.00216079
# [30]	training's binary_logloss: 0.00124214	valid_1's binary_logloss: 0.00213014
# [40]	training's binary_logloss: 0.00106329	valid_1's binary_logloss: 0.00210417
# [50]	training's binary_logloss: 0.000923261	valid_1's binary_logloss: 0.00208256
# [60]	training's binary_logloss: 0.000809088	valid_1's binary_logloss: 0.00206498
# [70]	training's binary_logloss: 0.000713644	valid_1's binary_logloss: 0.00205109
# [80]	training's binary_logloss: 0.0006323	valid_1's binary_logloss: 0.00204029
# [90]	training's binary_logloss: 0.000562261	valid_1's binary_logloss: 0.00203245
# [100]	training's binary_logloss: 0.000501393	valid_1's binary_logloss: 0.00202736
# [110]	training's binary_logloss: 0.000448141	valid_1's binary_logloss: 0.00202473
# [120]	training's binary_logloss: 0.000401267	valid_1's binary_logloss: 0.00202434
# Early stopping, best iteration is:
# [117]	training's binary_logloss: 0.000414718	valid_1's binary_logloss: 0.00202421
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00159869	valid_1's binary_logloss: 0.00518093
# [20]	training's binary_logloss: 0.00123786	valid_1's binary_logloss: 0.00502424
# [30]	training's binary_logloss: 0.00102476	valid_1's binary_logloss: 0.00487004
# [40]	training's binary_logloss: 0.000873238	valid_1's binary_logloss: 0.00476729
# [50]	training's binary_logloss: 0.000756046	valid_1's binary_logloss: 0.004694
# [60]	training's binary_logloss: 0.000661159	valid_1's binary_logloss: 0.00462049
# [70]	training's binary_logloss: 0.000582132	valid_1's binary_logloss: 0.00458506
# [80]	training's binary_logloss: 0.000515137	valid_1's binary_logloss: 0.00456296
# [90]	training's binary_logloss: 0.000457606	valid_1's binary_logloss: 0.00454622
# [100]	training's binary_logloss: 0.000407704	valid_1's binary_logloss: 0.00454509
# Early stopping, best iteration is:
# [94]	training's binary_logloss: 0.000436813	valid_1's binary_logloss: 0.00454088
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00136957	valid_1's binary_logloss: 0.00626295
# [20]	training's binary_logloss: 0.0010724	valid_1's binary_logloss: 0.0061802
# [30]	training's binary_logloss: 0.000889946	valid_1's binary_logloss: 0.00615522
# Early stopping, best iteration is:
# [22]	training's binary_logloss: 0.00102959	valid_1's binary_logloss: 0.00614554
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00159917	valid_1's binary_logloss: 0.00435726
# [20]	training's binary_logloss: 0.00123499	valid_1's binary_logloss: 0.00426642
# [30]	training's binary_logloss: 0.00102436	valid_1's binary_logloss: 0.00419664
# [40]	training's binary_logloss: 0.000874476	valid_1's binary_logloss: 0.00413226
# [50]	training's binary_logloss: 0.000757278	valid_1's binary_logloss: 0.00408046
# [60]	training's binary_logloss: 0.000662196	valid_1's binary_logloss: 0.00404501
# [70]	training's binary_logloss: 0.000582764	valid_1's binary_logloss: 0.0040224
# [80]	training's binary_logloss: 0.000515524	valid_1's binary_logloss: 0.00401306
# [90]	training's binary_logloss: 0.000457785	valid_1's binary_logloss: 0.0040085
# [100]	training's binary_logloss: 0.000407715	valid_1's binary_logloss: 0.00399693
# [110]	training's binary_logloss: 0.000363986	valid_1's binary_logloss: 0.00399985
# Early stopping, best iteration is:
# [108]	training's binary_logloss: 0.000372277	valid_1's binary_logloss: 0.00399586
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00196636	valid_1's binary_logloss: 0.00215286
# [20]	training's binary_logloss: 0.00151693	valid_1's binary_logloss: 0.00212496
# [30]	training's binary_logloss: 0.00125498	valid_1's binary_logloss: 0.00209915
# [40]	training's binary_logloss: 0.00106899	valid_1's binary_logloss: 0.00207705
# [50]	training's binary_logloss: 0.000924825	valid_1's binary_logloss: 0.00205899
# [60]	training's binary_logloss: 0.000808069	valid_1's binary_logloss: 0.00204478
# [70]	training's binary_logloss: 0.000711146	valid_1's binary_logloss: 0.00203345
# [80]	training's binary_logloss: 0.000629077	valid_1's binary_logloss: 0.00202466
# [90]	training's binary_logloss: 0.000558645	valid_1's binary_logloss: 0.00201894
# [100]	training's binary_logloss: 0.000497636	valid_1's binary_logloss: 0.00201525
# [110]	training's binary_logloss: 0.000444359	valid_1's binary_logloss: 0.00201394
# [120]	training's binary_logloss: 0.00039756	valid_1's binary_logloss: 0.00201465
# Early stopping, best iteration is:
# [112]	training's binary_logloss: 0.000434513	valid_1's binary_logloss: 0.00201388
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0596877	valid_1's binary_logloss: 0.0523079
# [20]	training's binary_logloss: 0.0560736	valid_1's binary_logloss: 0.0518722
# [30]	training's binary_logloss: 0.053127	valid_1's binary_logloss: 0.0514839
# [40]	training's binary_logloss: 0.0507361	valid_1's binary_logloss: 0.0511093
# [50]	training's binary_logloss: 0.0488575	valid_1's binary_logloss: 0.0507525
# [60]	training's binary_logloss: 0.0471216	valid_1's binary_logloss: 0.0504525
# [70]	training's binary_logloss: 0.0455038	valid_1's binary_logloss: 0.0502353
# [80]	training's binary_logloss: 0.0439916	valid_1's binary_logloss: 0.0499705
# [90]	training's binary_logloss: 0.0425014	valid_1's binary_logloss: 0.0497672
# [100]	training's binary_logloss: 0.0411237	valid_1's binary_logloss: 0.0495656
# [110]	training's binary_logloss: 0.039786	valid_1's binary_logloss: 0.0493739
# [120]	training's binary_logloss: 0.0385971	valid_1's binary_logloss: 0.0491701
# [130]	training's binary_logloss: 0.037438	valid_1's binary_logloss: 0.0490369
# [140]	training's binary_logloss: 0.0362823	valid_1's binary_logloss: 0.0488745
# [150]	training's binary_logloss: 0.0352283	valid_1's binary_logloss: 0.048726
# [160]	training's binary_logloss: 0.0342314	valid_1's binary_logloss: 0.0485754
# [170]	training's binary_logloss: 0.0332624	valid_1's binary_logloss: 0.0484585
# [180]	training's binary_logloss: 0.0323443	valid_1's binary_logloss: 0.0482988
# [190]	training's binary_logloss: 0.0314085	valid_1's binary_logloss: 0.0482286
# [200]	training's binary_logloss: 0.030613	valid_1's binary_logloss: 0.0481554
# [210]	training's binary_logloss: 0.0298472	valid_1's binary_logloss: 0.0480854
# [220]	training's binary_logloss: 0.0291273	valid_1's binary_logloss: 0.0480208
# [230]	training's binary_logloss: 0.0283744	valid_1's binary_logloss: 0.0479563
# [240]	training's binary_logloss: 0.0276522	valid_1's binary_logloss: 0.0478375
# [250]	training's binary_logloss: 0.0269778	valid_1's binary_logloss: 0.0478061
# [260]	training's binary_logloss: 0.0264177	valid_1's binary_logloss: 0.0477675
# [270]	training's binary_logloss: 0.025729	valid_1's binary_logloss: 0.0477182
# [280]	training's binary_logloss: 0.025215	valid_1's binary_logloss: 0.047671
# [290]	training's binary_logloss: 0.0245534	valid_1's binary_logloss: 0.047579
# [300]	training's binary_logloss: 0.0240348	valid_1's binary_logloss: 0.0475495
# [310]	training's binary_logloss: 0.0235085	valid_1's binary_logloss: 0.0475254
# [320]	training's binary_logloss: 0.0228404	valid_1's binary_logloss: 0.047475
# [330]	training's binary_logloss: 0.022293	valid_1's binary_logloss: 0.0474803
# Early stopping, best iteration is:
# [326]	training's binary_logloss: 0.0225261	valid_1's binary_logloss: 0.047447
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0594757	valid_1's binary_logloss: 0.0560431
# [20]	training's binary_logloss: 0.0562305	valid_1's binary_logloss: 0.055711
# [30]	training's binary_logloss: 0.0534395	valid_1's binary_logloss: 0.0554669
# [40]	training's binary_logloss: 0.0510186	valid_1's binary_logloss: 0.0551526
# [50]	training's binary_logloss: 0.0487115	valid_1's binary_logloss: 0.0549385
# [60]	training's binary_logloss: 0.0468564	valid_1's binary_logloss: 0.0545812
# [70]	training's binary_logloss: 0.0451699	valid_1's binary_logloss: 0.0543092
# [80]	training's binary_logloss: 0.0435536	valid_1's binary_logloss: 0.0540743
# [90]	training's binary_logloss: 0.0420736	valid_1's binary_logloss: 0.0538156
# [100]	training's binary_logloss: 0.0407046	valid_1's binary_logloss: 0.0535439
# [110]	training's binary_logloss: 0.0394478	valid_1's binary_logloss: 0.0533795
# [120]	training's binary_logloss: 0.0381256	valid_1's binary_logloss: 0.0532485
# [130]	training's binary_logloss: 0.03704	valid_1's binary_logloss: 0.0531419
# [140]	training's binary_logloss: 0.0358744	valid_1's binary_logloss: 0.052995
# [150]	training's binary_logloss: 0.0348624	valid_1's binary_logloss: 0.0528683
# [160]	training's binary_logloss: 0.0337781	valid_1's binary_logloss: 0.0528016
# [170]	training's binary_logloss: 0.0328183	valid_1's binary_logloss: 0.052716
# [180]	training's binary_logloss: 0.0318868	valid_1's binary_logloss: 0.0526256
# [190]	training's binary_logloss: 0.0309983	valid_1's binary_logloss: 0.0525786
# [200]	training's binary_logloss: 0.0301479	valid_1's binary_logloss: 0.0525349
# [210]	training's binary_logloss: 0.0292612	valid_1's binary_logloss: 0.0524878
# [220]	training's binary_logloss: 0.0283935	valid_1's binary_logloss: 0.0524569
# [230]	training's binary_logloss: 0.0276675	valid_1's binary_logloss: 0.052412
# [240]	training's binary_logloss: 0.0267906	valid_1's binary_logloss: 0.0523422
# [250]	training's binary_logloss: 0.0260856	valid_1's binary_logloss: 0.0523125
# [260]	training's binary_logloss: 0.0253703	valid_1's binary_logloss: 0.0522576
# [270]	training's binary_logloss: 0.024674	valid_1's binary_logloss: 0.0522922
# Early stopping, best iteration is:
# [264]	training's binary_logloss: 0.0250884	valid_1's binary_logloss: 0.0522499
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0560676	valid_1's binary_logloss: 0.0647706
# [20]	training's binary_logloss: 0.0522653	valid_1's binary_logloss: 0.0642132
# [30]	training's binary_logloss: 0.0492689	valid_1's binary_logloss: 0.0638018
# [40]	training's binary_logloss: 0.0468861	valid_1's binary_logloss: 0.0633982
# [50]	training's binary_logloss: 0.0447717	valid_1's binary_logloss: 0.0630709
# [60]	training's binary_logloss: 0.0430685	valid_1's binary_logloss: 0.0626662
# [70]	training's binary_logloss: 0.0413287	valid_1's binary_logloss: 0.0623656
# [80]	training's binary_logloss: 0.0398289	valid_1's binary_logloss: 0.06213
# [90]	training's binary_logloss: 0.0385968	valid_1's binary_logloss: 0.0619322
# [100]	training's binary_logloss: 0.0372645	valid_1's binary_logloss: 0.0617816
# [110]	training's binary_logloss: 0.0360831	valid_1's binary_logloss: 0.0616479
# [120]	training's binary_logloss: 0.0348804	valid_1's binary_logloss: 0.0615263
# [130]	training's binary_logloss: 0.0337629	valid_1's binary_logloss: 0.0615064
# [140]	training's binary_logloss: 0.0327031	valid_1's binary_logloss: 0.0613698
# [150]	training's binary_logloss: 0.0317048	valid_1's binary_logloss: 0.0613105
# [160]	training's binary_logloss: 0.0306682	valid_1's binary_logloss: 0.061236
# [170]	training's binary_logloss: 0.0297671	valid_1's binary_logloss: 0.061212
# Early stopping, best iteration is:
# [163]	training's binary_logloss: 0.0304271	valid_1's binary_logloss: 0.0611804
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0600379	valid_1's binary_logloss: 0.0555144
# [20]	training's binary_logloss: 0.0573615	valid_1's binary_logloss: 0.0548836
# [30]	training's binary_logloss: 0.0550504	valid_1's binary_logloss: 0.0543987
# [40]	training's binary_logloss: 0.0528379	valid_1's binary_logloss: 0.0539612
# [50]	training's binary_logloss: 0.0508794	valid_1's binary_logloss: 0.0535695
# [60]	training's binary_logloss: 0.0489851	valid_1's binary_logloss: 0.0531587
# [70]	training's binary_logloss: 0.047416	valid_1's binary_logloss: 0.0528371
# [80]	training's binary_logloss: 0.0460032	valid_1's binary_logloss: 0.0525728
# [90]	training's binary_logloss: 0.0447968	valid_1's binary_logloss: 0.0523428
# [100]	training's binary_logloss: 0.0435029	valid_1's binary_logloss: 0.0522073
# [110]	training's binary_logloss: 0.0422611	valid_1's binary_logloss: 0.051972
# [120]	training's binary_logloss: 0.0410211	valid_1's binary_logloss: 0.0518052
# [130]	training's binary_logloss: 0.0396258	valid_1's binary_logloss: 0.0516511
# [140]	training's binary_logloss: 0.03844	valid_1's binary_logloss: 0.0515291
# [150]	training's binary_logloss: 0.0373395	valid_1's binary_logloss: 0.0514059
# [160]	training's binary_logloss: 0.0360954	valid_1's binary_logloss: 0.0512998
# [170]	training's binary_logloss: 0.035101	valid_1's binary_logloss: 0.0511484
# [180]	training's binary_logloss: 0.0340335	valid_1's binary_logloss: 0.0510419
# [190]	training's binary_logloss: 0.0329951	valid_1's binary_logloss: 0.0509381
# [200]	training's binary_logloss: 0.0320129	valid_1's binary_logloss: 0.0508722
# [210]	training's binary_logloss: 0.031092	valid_1's binary_logloss: 0.0507638
# [220]	training's binary_logloss: 0.0302021	valid_1's binary_logloss: 0.0506603
# [230]	training's binary_logloss: 0.0293876	valid_1's binary_logloss: 0.050616
# [240]	training's binary_logloss: 0.0286388	valid_1's binary_logloss: 0.0505407
# [250]	training's binary_logloss: 0.0278279	valid_1's binary_logloss: 0.0504894
# [260]	training's binary_logloss: 0.0270741	valid_1's binary_logloss: 0.050464
# [270]	training's binary_logloss: 0.0263637	valid_1's binary_logloss: 0.0504785
# Early stopping, best iteration is:
# [266]	training's binary_logloss: 0.0266858	valid_1's binary_logloss: 0.0504379
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0530133	valid_1's binary_logloss: 0.0779977
# [20]	training's binary_logloss: 0.0498176	valid_1's binary_logloss: 0.0771106
# [30]	training's binary_logloss: 0.0473029	valid_1's binary_logloss: 0.076555
# [40]	training's binary_logloss: 0.0450775	valid_1's binary_logloss: 0.0759019
# [50]	training's binary_logloss: 0.042814	valid_1's binary_logloss: 0.0754472
# [60]	training's binary_logloss: 0.0410328	valid_1's binary_logloss: 0.0751478
# [70]	training's binary_logloss: 0.039662	valid_1's binary_logloss: 0.0749399
# [80]	training's binary_logloss: 0.0381687	valid_1's binary_logloss: 0.0747615
# [90]	training's binary_logloss: 0.0367601	valid_1's binary_logloss: 0.0745909
# [100]	training's binary_logloss: 0.035595	valid_1's binary_logloss: 0.0744212
# [110]	training's binary_logloss: 0.0344301	valid_1's binary_logloss: 0.0743337
# [120]	training's binary_logloss: 0.0334918	valid_1's binary_logloss: 0.0741659
# [130]	training's binary_logloss: 0.032517	valid_1's binary_logloss: 0.0740844
# [140]	training's binary_logloss: 0.0316309	valid_1's binary_logloss: 0.0740266
# [150]	training's binary_logloss: 0.0307304	valid_1's binary_logloss: 0.0740147
# [160]	training's binary_logloss: 0.0298195	valid_1's binary_logloss: 0.0739735
# [170]	training's binary_logloss: 0.0289888	valid_1's binary_logloss: 0.073945
# [180]	training's binary_logloss: 0.0281312	valid_1's binary_logloss: 0.0739848
# Early stopping, best iteration is:
# [171]	training's binary_logloss: 0.0289337	valid_1's binary_logloss: 0.0739293
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0773066	valid_1's binary_logloss: 0.075389
# [20]	training's binary_logloss: 0.0757636	valid_1's binary_logloss: 0.0749995
# [30]	training's binary_logloss: 0.0741538	valid_1's binary_logloss: 0.0747211
# [40]	training's binary_logloss: 0.0729571	valid_1's binary_logloss: 0.0744596
# [50]	training's binary_logloss: 0.0715574	valid_1's binary_logloss: 0.0741748
# [60]	training's binary_logloss: 0.0703958	valid_1's binary_logloss: 0.0739532
# [70]	training's binary_logloss: 0.0692521	valid_1's binary_logloss: 0.0737715
# [80]	training's binary_logloss: 0.0679583	valid_1's binary_logloss: 0.0736135
# [90]	training's binary_logloss: 0.0666129	valid_1's binary_logloss: 0.0734499
# [100]	training's binary_logloss: 0.065048	valid_1's binary_logloss: 0.0734011
# [110]	training's binary_logloss: 0.0635774	valid_1's binary_logloss: 0.0732725
# [120]	training's binary_logloss: 0.0619786	valid_1's binary_logloss: 0.0731323
# [130]	training's binary_logloss: 0.0606914	valid_1's binary_logloss: 0.0730867
# [140]	training's binary_logloss: 0.0594444	valid_1's binary_logloss: 0.073026
# [150]	training's binary_logloss: 0.058143	valid_1's binary_logloss: 0.0729935
# Early stopping, best iteration is:
# [149]	training's binary_logloss: 0.0583536	valid_1's binary_logloss: 0.0729835
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.076384	valid_1's binary_logloss: 0.0787509
# [20]	training's binary_logloss: 0.0747128	valid_1's binary_logloss: 0.0783699
# [30]	training's binary_logloss: 0.0732877	valid_1's binary_logloss: 0.0781859
# [40]	training's binary_logloss: 0.0720574	valid_1's binary_logloss: 0.0780205
# [50]	training's binary_logloss: 0.0705428	valid_1's binary_logloss: 0.0778938
# [60]	training's binary_logloss: 0.0690777	valid_1's binary_logloss: 0.0777008
# [70]	training's binary_logloss: 0.0675451	valid_1's binary_logloss: 0.0776331
# [80]	training's binary_logloss: 0.0661782	valid_1's binary_logloss: 0.0774254
# [90]	training's binary_logloss: 0.0650193	valid_1's binary_logloss: 0.0772121
# [100]	training's binary_logloss: 0.0638723	valid_1's binary_logloss: 0.0770802
# [110]	training's binary_logloss: 0.0626803	valid_1's binary_logloss: 0.0769143
# [120]	training's binary_logloss: 0.0616583	valid_1's binary_logloss: 0.0768291
# [130]	training's binary_logloss: 0.0606832	valid_1's binary_logloss: 0.0766599
# [140]	training's binary_logloss: 0.0596715	valid_1's binary_logloss: 0.0765653
# [150]	training's binary_logloss: 0.0586262	valid_1's binary_logloss: 0.0765688
# Early stopping, best iteration is:
# [145]	training's binary_logloss: 0.0591952	valid_1's binary_logloss: 0.076547
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0756942	valid_1's binary_logloss: 0.0812979
# [20]	training's binary_logloss: 0.0738578	valid_1's binary_logloss: 0.0809072
# [30]	training's binary_logloss: 0.0725	valid_1's binary_logloss: 0.0806235
# [40]	training's binary_logloss: 0.071055	valid_1's binary_logloss: 0.0802925
# [50]	training's binary_logloss: 0.0697148	valid_1's binary_logloss: 0.0799021
# [60]	training's binary_logloss: 0.0683464	valid_1's binary_logloss: 0.0796407
# [70]	training's binary_logloss: 0.066977	valid_1's binary_logloss: 0.0793823
# [80]	training's binary_logloss: 0.0657294	valid_1's binary_logloss: 0.0791866
# [90]	training's binary_logloss: 0.0644472	valid_1's binary_logloss: 0.0790653
# [100]	training's binary_logloss: 0.0631752	valid_1's binary_logloss: 0.0789652
# [110]	training's binary_logloss: 0.0621528	valid_1's binary_logloss: 0.0787499
# [120]	training's binary_logloss: 0.0610234	valid_1's binary_logloss: 0.0786932
# [130]	training's binary_logloss: 0.0598116	valid_1's binary_logloss: 0.0785632
# [140]	training's binary_logloss: 0.058656	valid_1's binary_logloss: 0.0784723
# [150]	training's binary_logloss: 0.0576371	valid_1's binary_logloss: 0.0784037
# [160]	training's binary_logloss: 0.0565778	valid_1's binary_logloss: 0.0783454
# [170]	training's binary_logloss: 0.0555259	valid_1's binary_logloss: 0.078361
# Early stopping, best iteration is:
# [161]	training's binary_logloss: 0.056516	valid_1's binary_logloss: 0.0783207
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0754271	valid_1's binary_logloss: 0.0824496
# [20]	training's binary_logloss: 0.0741517	valid_1's binary_logloss: 0.0820685
# [30]	training's binary_logloss: 0.0729385	valid_1's binary_logloss: 0.0818073
# [40]	training's binary_logloss: 0.0717058	valid_1's binary_logloss: 0.0814993
# [50]	training's binary_logloss: 0.0702238	valid_1's binary_logloss: 0.0812714
# [60]	training's binary_logloss: 0.0688672	valid_1's binary_logloss: 0.0810545
# [70]	training's binary_logloss: 0.0674388	valid_1's binary_logloss: 0.0809202
# [80]	training's binary_logloss: 0.0657909	valid_1's binary_logloss: 0.0808029
# [90]	training's binary_logloss: 0.0644292	valid_1's binary_logloss: 0.0806612
# [100]	training's binary_logloss: 0.0629805	valid_1's binary_logloss: 0.0805914
# [110]	training's binary_logloss: 0.0616434	valid_1's binary_logloss: 0.0804876
# [120]	training's binary_logloss: 0.060414	valid_1's binary_logloss: 0.0803778
# [130]	training's binary_logloss: 0.0590267	valid_1's binary_logloss: 0.0803109
# [140]	training's binary_logloss: 0.0578621	valid_1's binary_logloss: 0.0801769
# [150]	training's binary_logloss: 0.0566923	valid_1's binary_logloss: 0.0801008
# [160]	training's binary_logloss: 0.0555912	valid_1's binary_logloss: 0.0800416
# [170]	training's binary_logloss: 0.054426	valid_1's binary_logloss: 0.0800379
# Early stopping, best iteration is:
# [163]	training's binary_logloss: 0.0553313	valid_1's binary_logloss: 0.0800067
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0780335	valid_1's binary_logloss: 0.0720534
# [20]	training's binary_logloss: 0.0763738	valid_1's binary_logloss: 0.0718941
# [30]	training's binary_logloss: 0.07481	valid_1's binary_logloss: 0.0716887
# [40]	training's binary_logloss: 0.0735239	valid_1's binary_logloss: 0.0715801
# [50]	training's binary_logloss: 0.0722144	valid_1's binary_logloss: 0.0714428
# [60]	training's binary_logloss: 0.0709858	valid_1's binary_logloss: 0.0713626
# [70]	training's binary_logloss: 0.0694869	valid_1's binary_logloss: 0.071301
# [80]	training's binary_logloss: 0.0681576	valid_1's binary_logloss: 0.0712188
# [90]	training's binary_logloss: 0.0668445	valid_1's binary_logloss: 0.0711044
# [100]	training's binary_logloss: 0.065735	valid_1's binary_logloss: 0.070987
# [110]	training's binary_logloss: 0.0644827	valid_1's binary_logloss: 0.0708631
# [120]	training's binary_logloss: 0.0631757	valid_1's binary_logloss: 0.0706926
# [130]	training's binary_logloss: 0.0620185	valid_1's binary_logloss: 0.0705591
# [140]	training's binary_logloss: 0.0609004	valid_1's binary_logloss: 0.0704418
# [150]	training's binary_logloss: 0.0597063	valid_1's binary_logloss: 0.0703541
# [160]	training's binary_logloss: 0.0586037	valid_1's binary_logloss: 0.0702703
# [170]	training's binary_logloss: 0.0575644	valid_1's binary_logloss: 0.0702382
# [180]	training's binary_logloss: 0.0565552	valid_1's binary_logloss: 0.0702031
# [190]	training's binary_logloss: 0.0554715	valid_1's binary_logloss: 0.0701661
# [200]	training's binary_logloss: 0.0544901	valid_1's binary_logloss: 0.0701135
# [210]	training's binary_logloss: 0.0535422	valid_1's binary_logloss: 0.0700922
# [220]	training's binary_logloss: 0.0525263	valid_1's binary_logloss: 0.0700311
# [230]	training's binary_logloss: 0.0515395	valid_1's binary_logloss: 0.0700208
# [240]	training's binary_logloss: 0.0505322	valid_1's binary_logloss: 0.0700353
# Early stopping, best iteration is:
# [234]	training's binary_logloss: 0.0511612	valid_1's binary_logloss: 0.0699873
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0134793	valid_1's binary_logloss: 0.0186227
# [20]	training's binary_logloss: 0.0109695	valid_1's binary_logloss: 0.0177214
# [30]	training's binary_logloss: 0.00918351	valid_1's binary_logloss: 0.0168597
# [40]	training's binary_logloss: 0.00786901	valid_1's binary_logloss: 0.0163666
# [50]	training's binary_logloss: 0.00685077	valid_1's binary_logloss: 0.0159195
# [60]	training's binary_logloss: 0.00582691	valid_1's binary_logloss: 0.015638
# [70]	training's binary_logloss: 0.00510156	valid_1's binary_logloss: 0.0153353
# [80]	training's binary_logloss: 0.00452383	valid_1's binary_logloss: 0.0151789
# [90]	training's binary_logloss: 0.00405022	valid_1's binary_logloss: 0.0150785
# [100]	training's binary_logloss: 0.00367872	valid_1's binary_logloss: 0.0149794
# [110]	training's binary_logloss: 0.003352	valid_1's binary_logloss: 0.0149254
# [120]	training's binary_logloss: 0.00306475	valid_1's binary_logloss: 0.0148785
# [130]	training's binary_logloss: 0.00280324	valid_1's binary_logloss: 0.0148763
# Early stopping, best iteration is:
# [127]	training's binary_logloss: 0.00287928	valid_1's binary_logloss: 0.0148617
# Training until validation scores don't improve for 10 rounds
# ...
# Early stopping, best iteration is:
# [290]	training's binary_logloss: 0.00464537	valid_1's binary_logloss: 0.0161108
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0303316	valid_1's binary_logloss: 0.0399532
# [20]	training's binary_logloss: 0.0262571	valid_1's binary_logloss: 0.0373024
# [30]	training's binary_logloss: 0.0229534	valid_1's binary_logloss: 0.0352936
# [40]	training's binary_logloss: 0.0206091	valid_1's binary_logloss: 0.0338297
# [50]	training's binary_logloss: 0.0186161	valid_1's binary_logloss: 0.0328734
# [60]	training's binary_logloss: 0.0167838	valid_1's binary_logloss: 0.0319629
# [70]	training's binary_logloss: 0.01531	valid_1's binary_logloss: 0.0312859
# [80]	training's binary_logloss: 0.0139902	valid_1's binary_logloss: 0.0308135
# [90]	training's binary_logloss: 0.0128592	valid_1's binary_logloss: 0.0303118
# [100]	training's binary_logloss: 0.0118663	valid_1's binary_logloss: 0.0298789
# [110]	training's binary_logloss: 0.0109933	valid_1's binary_logloss: 0.0295521
# [120]	training's binary_logloss: 0.0102107	valid_1's binary_logloss: 0.0293016
# [130]	training's binary_logloss: 0.00952579	valid_1's binary_logloss: 0.0291231
# [140]	training's binary_logloss: 0.00892884	valid_1's binary_logloss: 0.028892
# [150]	training's binary_logloss: 0.00836744	valid_1's binary_logloss: 0.0287807
# [160]	training's binary_logloss: 0.00787645	valid_1's binary_logloss: 0.0286402
# [170]	training's binary_logloss: 0.00739686	valid_1's binary_logloss: 0.0285467
# [180]	training's binary_logloss: 0.00692973	valid_1's binary_logloss: 0.0284256
# [190]	training's binary_logloss: 0.00654823	valid_1's binary_logloss: 0.0283297
# [200]	training's binary_logloss: 0.00623962	valid_1's binary_logloss: 0.0282822
# [210]	training's binary_logloss: 0.00591301	valid_1's binary_logloss: 0.0282905
# Early stopping, best iteration is:
# [209]	training's binary_logloss: 0.00595022	valid_1's binary_logloss: 0.0282811
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0307642	valid_1's binary_logloss: 0.0395263
# [20]	training's binary_logloss: 0.0259035	valid_1's binary_logloss: 0.0372855
# [30]	training's binary_logloss: 0.0228482	valid_1's binary_logloss: 0.0358078
# [40]	training's binary_logloss: 0.0203945	valid_1's binary_logloss: 0.0345685
# [50]	training's binary_logloss: 0.0185289	valid_1's binary_logloss: 0.033547
# [60]	training's binary_logloss: 0.0169935	valid_1's binary_logloss: 0.032722
# [70]	training's binary_logloss: 0.0156197	valid_1's binary_logloss: 0.0320613
# [80]	training's binary_logloss: 0.0143561	valid_1's binary_logloss: 0.0314821
# [90]	training's binary_logloss: 0.0132026	valid_1's binary_logloss: 0.0310086
# [100]	training's binary_logloss: 0.0121329	valid_1's binary_logloss: 0.0306204
# [110]	training's binary_logloss: 0.0112391	valid_1's binary_logloss: 0.0302438
# [120]	training's binary_logloss: 0.0104268	valid_1's binary_logloss: 0.0299473
# [130]	training's binary_logloss: 0.00972977	valid_1's binary_logloss: 0.0297009
# [140]	training's binary_logloss: 0.00910783	valid_1's binary_logloss: 0.0294792
# [150]	training's binary_logloss: 0.00854431	valid_1's binary_logloss: 0.0293214
# [160]	training's binary_logloss: 0.00803209	valid_1's binary_logloss: 0.0291653
# [170]	training's binary_logloss: 0.00752996	valid_1's binary_logloss: 0.0290195
# [180]	training's binary_logloss: 0.0070796	valid_1's binary_logloss: 0.0289575
# [190]	training's binary_logloss: 0.00667914	valid_1's binary_logloss: 0.028912
# [200]	training's binary_logloss: 0.00626718	valid_1's binary_logloss: 0.0288759
# [210]	training's binary_logloss: 0.00591388	valid_1's binary_logloss: 0.0289643
# Early stopping, best iteration is:
# [200]	training's binary_logloss: 0.00626718	valid_1's binary_logloss: 0.0288759
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0306612	valid_1's binary_logloss: 0.0374844
# [20]	training's binary_logloss: 0.0261648	valid_1's binary_logloss: 0.0356245
# [30]	training's binary_logloss: 0.0231904	valid_1's binary_logloss: 0.0342435
# [40]	training's binary_logloss: 0.0207477	valid_1's binary_logloss: 0.0333198
# [50]	training's binary_logloss: 0.0188195	valid_1's binary_logloss: 0.0324922
# [60]	training's binary_logloss: 0.017203	valid_1's binary_logloss: 0.0319191
# [70]	training's binary_logloss: 0.0157844	valid_1's binary_logloss: 0.0314073
# [80]	training's binary_logloss: 0.0146709	valid_1's binary_logloss: 0.0310436
# [90]	training's binary_logloss: 0.0136018	valid_1's binary_logloss: 0.0307287
# [100]	training's binary_logloss: 0.0125475	valid_1's binary_logloss: 0.0305379
# [110]	training's binary_logloss: 0.0115338	valid_1's binary_logloss: 0.030362
# [120]	training's binary_logloss: 0.0106524	valid_1's binary_logloss: 0.0301573
# [130]	training's binary_logloss: 0.00990995	valid_1's binary_logloss: 0.0299959
# [140]	training's binary_logloss: 0.00925573	valid_1's binary_logloss: 0.0299229
# [150]	training's binary_logloss: 0.0086366	valid_1's binary_logloss: 0.0298768
# [160]	training's binary_logloss: 0.00809275	valid_1's binary_logloss: 0.0297873
# [170]	training's binary_logloss: 0.00756425	valid_1's binary_logloss: 0.0297766
# [180]	training's binary_logloss: 0.00709727	valid_1's binary_logloss: 0.029767
# [190]	training's binary_logloss: 0.00667271	valid_1's binary_logloss: 0.0297373
# [200]	training's binary_logloss: 0.00627991	valid_1's binary_logloss: 0.029759
# Early stopping, best iteration is:
# [195]	training's binary_logloss: 0.00646618	valid_1's binary_logloss: 0.0297363
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0296815	valid_1's binary_logloss: 0.041151
# [20]	training's binary_logloss: 0.0251681	valid_1's binary_logloss: 0.0388418
# [30]	training's binary_logloss: 0.0220577	valid_1's binary_logloss: 0.0372508
# [40]	training's binary_logloss: 0.0196934	valid_1's binary_logloss: 0.0363955
# [50]	training's binary_logloss: 0.0179021	valid_1's binary_logloss: 0.03568
# [60]	training's binary_logloss: 0.0163527	valid_1's binary_logloss: 0.0351339
# [70]	training's binary_logloss: 0.0150086	valid_1's binary_logloss: 0.0346168
# [80]	training's binary_logloss: 0.0138078	valid_1's binary_logloss: 0.0343486
# [90]	training's binary_logloss: 0.0127014	valid_1's binary_logloss: 0.0340567
# [100]	training's binary_logloss: 0.0117381	valid_1's binary_logloss: 0.0338967
# [110]	training's binary_logloss: 0.0108553	valid_1's binary_logloss: 0.0337828
# [120]	training's binary_logloss: 0.010048	valid_1's binary_logloss: 0.0335655
# [130]	training's binary_logloss: 0.00929043	valid_1's binary_logloss: 0.0333368
# [140]	training's binary_logloss: 0.00863664	valid_1's binary_logloss: 0.0331942
# [150]	training's binary_logloss: 0.00806707	valid_1's binary_logloss: 0.0331213
# [160]	training's binary_logloss: 0.00756372	valid_1's binary_logloss: 0.0331018
# [170]	training's binary_logloss: 0.00710662	valid_1's binary_logloss: 0.0330632
# [180]	training's binary_logloss: 0.00669704	valid_1's binary_logloss: 0.0330722
# Early stopping, best iteration is:
# [171]	training's binary_logloss: 0.00706659	valid_1's binary_logloss: 0.0330446
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00549487	valid_1's binary_logloss: 0.00547225
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00863353	valid_1's binary_logloss: 0.00544497
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00443034	valid_1's binary_logloss: 0.00969438
# Early stopping, best iteration is:
# [9]	training's binary_logloss: 0.00458594	valid_1's binary_logloss: 0.0096875
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00418537	valid_1's binary_logloss: 0.0112612
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00727444	valid_1's binary_logloss: 0.0111618
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00523748	valid_1's binary_logloss: 0.00830321
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00810719	valid_1's binary_logloss: 0.00826259
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00498325	valid_1's binary_logloss: 0.0082312
# Early stopping, best iteration is:
# [2]	training's binary_logloss: 0.00790311	valid_1's binary_logloss: 0.00818239
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00692739	valid_1's binary_logloss: 0.010659
# [20]	training's binary_logloss: 0.00532386	valid_1's binary_logloss: 0.0102636
# [30]	training's binary_logloss: 0.00417202	valid_1's binary_logloss: 0.00998316
# [40]	training's binary_logloss: 0.00346256	valid_1's binary_logloss: 0.00973662
# [50]	training's binary_logloss: 0.0029727	valid_1's binary_logloss: 0.00948472
# [60]	training's binary_logloss: 0.00259277	valid_1's binary_logloss: 0.00926548
# [70]	training's binary_logloss: 0.00228338	valid_1's binary_logloss: 0.00906961
# [80]	training's binary_logloss: 0.00202295	valid_1's binary_logloss: 0.00889311
# [90]	training's binary_logloss: 0.00180086	valid_1's binary_logloss: 0.00874694
# [100]	training's binary_logloss: 0.00160914	valid_1's binary_logloss: 0.00867369
# [110]	training's binary_logloss: 0.00144237	valid_1's binary_logloss: 0.00855279
# [120]	training's binary_logloss: 0.00129585	valid_1's binary_logloss: 0.00848398
# [130]	training's binary_logloss: 0.00116647	valid_1's binary_logloss: 0.00847373
# [140]	training's binary_logloss: 0.00105119	valid_1's binary_logloss: 0.0084341
# [150]	training's binary_logloss: 0.000949041	valid_1's binary_logloss: 0.008424
# [160]	training's binary_logloss: 0.000856593	valid_1's binary_logloss: 0.00841186
# Early stopping, best iteration is:
# [158]	training's binary_logloss: 0.000874385	valid_1's binary_logloss: 0.008405
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00655653	valid_1's binary_logloss: 0.00782349
# [20]	training's binary_logloss: 0.00521029	valid_1's binary_logloss: 0.00727374
# [30]	training's binary_logloss: 0.00432686	valid_1's binary_logloss: 0.0068761
# [40]	training's binary_logloss: 0.00366124	valid_1's binary_logloss: 0.0066365
# [50]	training's binary_logloss: 0.00318921	valid_1's binary_logloss: 0.00648985
# [60]	training's binary_logloss: 0.0027513	valid_1's binary_logloss: 0.00639411
# [70]	training's binary_logloss: 0.00240275	valid_1's binary_logloss: 0.00629276
# [80]	training's binary_logloss: 0.00211702	valid_1's binary_logloss: 0.00618978
# [90]	training's binary_logloss: 0.00187958	valid_1's binary_logloss: 0.0060968
# [100]	training's binary_logloss: 0.00167626	valid_1's binary_logloss: 0.00603783
# [110]	training's binary_logloss: 0.00150109	valid_1's binary_logloss: 0.00597542
# [120]	training's binary_logloss: 0.00134713	valid_1's binary_logloss: 0.00594086
# [130]	training's binary_logloss: 0.00121095	valid_1's binary_logloss: 0.00590166
# [140]	training's binary_logloss: 0.00109056	valid_1's binary_logloss: 0.00586446
# [150]	training's binary_logloss: 0.000984113	valid_1's binary_logloss: 0.00585253
# [160]	training's binary_logloss: 0.000887914	valid_1's binary_logloss: 0.00584807
# Early stopping, best iteration is:
# [156]	training's binary_logloss: 0.000925109	valid_1's binary_logloss: 0.00584369
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00587615	valid_1's binary_logloss: 0.0100529
# [20]	training's binary_logloss: 0.00491599	valid_1's binary_logloss: 0.00972576
# [30]	training's binary_logloss: 0.00381912	valid_1's binary_logloss: 0.00946522
# [40]	training's binary_logloss: 0.00322736	valid_1's binary_logloss: 0.00928313
# [50]	training's binary_logloss: 0.00279397	valid_1's binary_logloss: 0.00914329
# [60]	training's binary_logloss: 0.00245133	valid_1's binary_logloss: 0.00903313
# [70]	training's binary_logloss: 0.00216449	valid_1's binary_logloss: 0.00895115
# [80]	training's binary_logloss: 0.00191791	valid_1's binary_logloss: 0.00889438
# [90]	training's binary_logloss: 0.00170289	valid_1's binary_logloss: 0.0088611
# [100]	training's binary_logloss: 0.00152156	valid_1's binary_logloss: 0.00884487
# [110]	training's binary_logloss: 0.0013637	valid_1's binary_logloss: 0.00883945
# [120]	training's binary_logloss: 0.00122091	valid_1's binary_logloss: 0.00883723
# Early stopping, best iteration is:
# [116]	training's binary_logloss: 0.00127566	valid_1's binary_logloss: 0.00883505
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00604205	valid_1's binary_logloss: 0.0104729
# [20]	training's binary_logloss: 0.00492227	valid_1's binary_logloss: 0.0101748
# [30]	training's binary_logloss: 0.00394661	valid_1's binary_logloss: 0.0100437
# [40]	training's binary_logloss: 0.00326093	valid_1's binary_logloss: 0.00994755
# [50]	training's binary_logloss: 0.00280198	valid_1's binary_logloss: 0.00986794
# [60]	training's binary_logloss: 0.00244634	valid_1's binary_logloss: 0.00981971
# [70]	training's binary_logloss: 0.00215459	valid_1's binary_logloss: 0.00979449
# [80]	training's binary_logloss: 0.0019123	valid_1's binary_logloss: 0.00976721
# [90]	training's binary_logloss: 0.00170535	valid_1's binary_logloss: 0.0097546
# [100]	training's binary_logloss: 0.00153346	valid_1's binary_logloss: 0.00975319
# [110]	training's binary_logloss: 0.00138018	valid_1's binary_logloss: 0.00971764
# [120]	training's binary_logloss: 0.00124347	valid_1's binary_logloss: 0.00968895
# [130]	training's binary_logloss: 0.00112276	valid_1's binary_logloss: 0.00968353
# [140]	training's binary_logloss: 0.00101609	valid_1's binary_logloss: 0.00967945
# Early stopping, best iteration is:
# [135]	training's binary_logloss: 0.00106764	valid_1's binary_logloss: 0.00967662
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00640224	valid_1's binary_logloss: 0.00793581
# [20]	training's binary_logloss: 0.00488062	valid_1's binary_logloss: 0.00748676
# [30]	training's binary_logloss: 0.0039533	valid_1's binary_logloss: 0.00734967
# [40]	training's binary_logloss: 0.00334196	valid_1's binary_logloss: 0.00722277
# [50]	training's binary_logloss: 0.00288432	valid_1's binary_logloss: 0.00712395
# [60]	training's binary_logloss: 0.00252565	valid_1's binary_logloss: 0.00706658
# [70]	training's binary_logloss: 0.00223142	valid_1's binary_logloss: 0.00702943
# [80]	training's binary_logloss: 0.0019838	valid_1's binary_logloss: 0.00700867
# [90]	training's binary_logloss: 0.00177199	valid_1's binary_logloss: 0.00699307
# [100]	training's binary_logloss: 0.00158873	valid_1's binary_logloss: 0.00699656
# Early stopping, best iteration is:
# [95]	training's binary_logloss: 0.00167721	valid_1's binary_logloss: 0.0069916
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00532671	valid_1's binary_logloss: 0.0140925
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00811071	valid_1's binary_logloss: 0.0139829
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0054991	valid_1's binary_logloss: 0.0125462
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00859019	valid_1's binary_logloss: 0.0125283
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0067314	valid_1's binary_logloss: 0.00833343
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.00959924	valid_1's binary_logloss: 0.00828624
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.00719279	valid_1's binary_logloss: 0.00424242
# Early stopping, best iteration is:
# [1]	training's binary_logloss: 0.0106665	valid_1's binary_logloss: 0.00421461
# Training until validation scores don't improve for 10 rounds
# [10]	training's binary_logloss: 0.0059169	valid_1's binary_logloss: 0.00952894
# Early stopping, best iteration is:
# [2]	training's binary_logloss: 0.00867951	valid_1's binary_logloss: 0.0094722

# %%
scores = []
for target_col in train_targets_scored.columns:
    if target_col != "sig_id":
        scores.append(log_loss(train_targets_scored[target_col], oof[target_col]))
print(np.mean(scores))
# Out:
# 0.016258159041418075

# %%
sub.to_csv('submission.csv', index=False)
